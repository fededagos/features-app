# %%
from dash import Dash, dcc, html, Input, Output, no_update
import pandas as pd
import pathlib
from app import app
from utils.plotting import make_figure
import plotly.graph_objects as go
import numpy as np
# %load_ext autoreload
# %autoreload 3

# %%
df = pd.read_csv("datasets/all_features.csv")

# %%
selection = df["feature"].unique()[:5].tolist()

# %%
make_figure(df, which=selection)

# %%
np.array((np.array(["temporal", "waveform"]) == "temporal")).any()
# Out:
# True

# %%
list([1,2,3])
# Out:
# [1, 2, 3]

# %%
from matplotlib import colors

"rgba" + str(colors.to_rgba('blue')[:-1] + (0.5,))
# Out:
# 'rgba(0.0, 0.0, 1.0, 0.5)'

# %%
# Out:
# (0, 1, 2, 3, 4)
